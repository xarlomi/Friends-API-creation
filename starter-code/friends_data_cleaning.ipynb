# %%
import pandas as pd

# %%
vote_friends = pd.read_csv("friends_episodes_v2.csv")

# %%
vote_friends.head()
# Out:
#    Year_of_prod  Season                                   Episode_Title  \
# 0          1994       1            The One with the Sonogram at the End
# 1          1994       1                          The One with the Thumb
# 2          1994       1              The One with George Stephanopoulos
# 3          1994       1  The One with the East German Laundry Detergent
# 4          1994       1                           The One with the Butt
#
#    Duration                                            Summary  \
# 0        22  Ross finds out his ex-wife is pregnant. Rachel...
# 1        22  Monica becomes irritated when everyone likes h...
# 2        22  Joey and Chandler take Ross to a hockey game t...
# 3        22  Eager to spend time with Rachel, Ross pretends...
# 4        22  Monica's obsessiveness is put to the test afte...
#
#          Director  Stars  Votes
# 0   James Burrows    8.1   4888
# 1   James Burrows    8.2   4605
# 2   James Burrows    8.1   4468
# ...

# %%
vote_friends.Votes.max()
# Out:
# 10381

# %%
votes = vote_friends.nlargest(10, ["Votes"])

# %%
votes.sort_values('Season')
# Out:
#      Year_of_prod  Season                         Episode_Title  Duration  \
# 5            1994       1             The One with the Blackout        22
# 0            1994       1  The One with the Sonogram at the End        22
# 1            1994       1                The One with the Thumb        22
# 36           1996       2           The One with the Prom Video        22
# 48           1996       3          The One Where No One's Ready        22
# 83           1998       4              The One with the Embryos        22
# 109          1999       5     The One Where Everybody Finds Out        22
# 177          2001       8                The One with the Rumor        22
# 234          2004      10                          The Last One        30
# 233          2004      10                          The Last One        30
#
#                                                Summary         Director  \
# 5    When New York suffers from a blackout, Ross tr...    James Burrows
# ...

# %% [markdown]
# ## Let´s take then season 1 ep: 0, 1 and 5:

# %%
#This is to display all row content, because default is truncated
pd.set_option('display.max_colwidth', None)

# %%
friends_quotes = pd.read_csv("friends_quotes.csv")

# %%
friends_quotes.head()
# Out:
#      author  episode_number           episode_title  \
# 0    Monica             1.0  Monica Gets A Roommate
# 1      Joey             1.0  Monica Gets A Roommate
# 2  Chandler             1.0  Monica Gets A Roommate
# 3    Phoebe             1.0  Monica Gets A Roommate
# 4    Phoebe             1.0  Monica Gets A Roommate
#
#                                                                               quote  \
# 0                          There's nothing to tell! He's just some guy I work with!
# 1  C'mon, you're going out with the guy! There's gotta be something wrong with him!
# 2          All right Joey, be nice. So does he have a hump? A hump and a hairpiece?
# 3                                                          Wait, does he eat chalk?
# 4   Just, 'cause, I don't want her to go through what I went through with Carl- oh!
#
#    quote_order  season
# 0          0.0     1.0
# 1          1.0     1.0
# 2          2.0     1.0
# 3          3.0     1.0
# 4          4.0     1.0

# %%
friends_quotes.quote[friends_quotes['episode_title']== "The One With The Blackout"]
# Out:
# Series([], Name: quote, dtype: object)

# %%
pd.set_option('display.max_colwidth', None)
sono= pd.DataFrame(friends_quotes[friends_quotes["episode_title"] == "The Sonogram At The End"])

# %%
sono
# Out:
#      author  episode_number            episode_title  \
# 300  Monica             2.0  The Sonogram At The End
# 301    Joey             2.0  The Sonogram At The End
# 302  Phoebe             2.0  The Sonogram At The End
# 303  Rachel             2.0  The Sonogram At The End
# 304  Monica             2.0  The Sonogram At The End
# ..      ...             ...                      ...
# 538    Ross             2.0  The Sonogram At The End
# 539  Monica             2.0  The Sonogram At The End
# 540    Ross             2.0  The Sonogram At The End
# 541  Monica             2.0  The Sonogram At The End
# 542  Rachel             2.0  The Sonogram At The End
#
# ...

# %%
sono["author"].unique()
# Out:
# array(['Monica', 'Joey', 'Phoebe', 'Rachel', 'Chandler', 'Ross', 'Marsha',
#        'Carol', 'All', 'Chandler and Joey', 'Mrs. Geller', 'Mr. Geller',
#        'Susan', 'Barry', 'Robbie', 'Bernice', 'Dr. Oberman'], dtype=object)

# %%
black = pd.DataFrame(friends_quotes[friends_quotes["episode_title"] == "The Blackout"])

# %%
black
# Out:
#         author  episode_number episode_title  \
# 1506    Rachel             7.0  The Blackout
# 1507    Phoebe             7.0  The Blackout
# 1508  Chandler             7.0  The Blackout
# 1509    Rachel             7.0  The Blackout
# 1510    Monica             7.0  The Blackout
# ...        ...             ...           ...
# 1731      Joey             7.0  The Blackout
# 1732      Jill             7.0  The Blackout
# 1733  Chandler             7.0  The Blackout
# 1734      Jill             7.0  The Blackout
# 1735  Chandler             7.0  The Blackout
#
#                                                   quote  quote_order  season
# 1506  Everybody? Shh, shhh. Uhhh... Central Perk is ...          0.0     1.0
# 1507  Hi. Um, I want to start with a song thats abou...          1.0     1.0
# 1508                         Oh, great. This is just...          2.0     1.0
# 1509  Wow, this is so cool, you guys. The entire cit...          3.0     1.0
# ...

# %%
black["author"].unique()
# Out:
# array(['Rachel', 'Phoebe', 'Chandler', 'Monica', 'Jill', 'Joey', 'Ross',
#        'All', 'Monica, Joey, and Phoebe', 'Mr. Heckles', 'Paolo'],
#       dtype=object)

# %%
thumb = pd.DataFrame(friends_quotes[friends_quotes["episode_title"] == "The Thumb"])

# %%
thumb
# Out:
#        author  episode_number episode_title  \
# 543    Phoebe             3.0     The Thumb
# 544       All             3.0     The Thumb
# 545      Ross             3.0     The Thumb
# 546    Phoebe             3.0     The Thumb
# 547       All             3.0     The Thumb
# ..        ...             ...           ...
# 796  Chandler             3.0     The Thumb
# 797       All             3.0     The Thumb
# 798  Chandler             3.0     The Thumb
# 799    Phoebe             3.0     The Thumb
# 800  Chandler             3.0     The Thumb
#
#                                                  quote  quote_order  season
# 543                                (entering) Hi guys!          0.0     1.0
# 544                                   Hey, Pheebs! Hi!          1.0     1.0
# 545                          Hey. Oh, oh, how'd it go?          2.0     1.0
# 546  Um, not so good. He walked me to the subway an...          3.0     1.0
# ...

# %%
thumb["author"].unique()
# Out:
# array(['Phoebe', 'All', 'Ross', 'Rachel', 'Monica', 'Joey', 'Chandler',
#        'Paula', 'Alan', 'The Guys', 'Lizzie'], dtype=object)

# %%
total_series = [thumb, black, sono]

# %%
series= pd.concat(total_series)

# %%
series
# Out:
#      author  episode_number            episode_title  \
# 543  Phoebe             3.0                The Thumb
# 544     All             3.0                The Thumb
# 545    Ross             3.0                The Thumb
# 546  Phoebe             3.0                The Thumb
# 547     All             3.0                The Thumb
# ..      ...             ...                      ...
# 538    Ross             2.0  The Sonogram At The End
# 539  Monica             2.0  The Sonogram At The End
# 540    Ross             2.0  The Sonogram At The End
# 541  Monica             2.0  The Sonogram At The End
# 542  Rachel             2.0  The Sonogram At The End
#
#                                                  quote  quote_order  season
# 543                                (entering) Hi guys!          0.0     1.0
# 544                                   Hey, Pheebs! Hi!          1.0     1.0
# 545                          Hey. Oh, oh, how'd it go?          2.0     1.0
# ...

# %%
series.to_csv("friends_data.csv")

# %%
series.sort_values("episode_number")
# Out:
#            author  episode_number            episode_title  \
# 542        Rachel             2.0  The Sonogram At The End
# 385          Ross             2.0  The Sonogram At The End
# 384   Mrs. Geller             2.0  The Sonogram At The End
# 383        Monica             2.0  The Sonogram At The End
# 382   Mrs. Geller             2.0  The Sonogram At The End
# ...           ...             ...                      ...
# 1652       Phoebe             7.0             The Blackout
# 1651  Mr. Heckles             7.0             The Blackout
# 1650       Rachel             7.0             The Blackout
# 1662       Rachel             7.0             The Blackout
# 1613         Joey             7.0             The Blackout
#
# ...

# %%
series.episode_title.unique()
# Out:
# array(['The Thumb', 'The Blackout', 'The Sonogram At The End'],
#       dtype=object)
